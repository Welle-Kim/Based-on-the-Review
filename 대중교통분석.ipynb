# %% [markdown]
# <a href="https://colab.research.google.com/github/Welle-Kim/Based-on-the-Review/blob/master/%EB%8C%80%EC%A4%91%EA%B5%90%ED%86%B5%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
f=open("subwayfree.csv",encoding="cp949")
data=csv.reader(f)
next(data)

for row in data:
  for i in range(4,8):
    row[i]=int(row[i])

  print(row)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ['201512', '5호선', '장한평', '504941', 102975, 504360, 104397, 20160108]
# ['201512', '5호선', '까치산', '816909', 150987, 758625, 151556, 20160108]
# ['201512', '5호선', '여의나루', '195172', 27779, 214711, 27795, 20160108]
# ['201512', '5호선', '동대문역사문화공원', '83288', 11380, 102003, 12512, 20160108]
# ['201512', '5호선', '고덕', '219276', 58705, 215763, 56614, 20160108]
# ['201512', '5호선', '군자', '317634', 37430, 351429, 41872, 20160108]
# ['201512', '5호선', '개화산', '157855', 33093, 145262, 32544, 20160108]
# ['201512', '5호선', '강동', '535007', 95789, 439185, 86084, 20160108]
# ['201512', '5호선', '행당', '222825', 48060, 191129, 43879, 20160108]
# ['201512', '5호선', '천호', '558162', 150388, 587791, 160847, 20160108]
# ['201512', '5호선', '둔촌동', '353707', 77465, 350190, 81030, 20160108]
# ['201512', '5호선', '아차산', '395058', 91935, 373291, 85141, 20160108]
# ['201512', '5호선', '길동', '188555', 58029, 198513, 59990, 20160108]
# ...

# %% [markdown]
# ##유임 승차 비율리 가장 높은 역은 어디?
# #### rate=유임 승차 인원/무임 승차 인원, 비율 데이터를 저장할 변수
#
# ###mx=0, rate의 최댓값을 저장할 변수

# %%
import csv
f=open("subwayfree.csv",encoding="cp949")
data=csv.reader(f)
next(data)
mx=0
rate=0

for row in data:
  for i in range(4,8):
    row[i]=int(row[i])
  if row[6]!=0:
    rate=row[4]/row[6]
    if rate>mx:
      mx=rate
      print(row,round(rate,2))
# Out:
# ['202202', '1호선', '종로3가', '335905', 211468, 308127, 197301, 20220303] 1.07
# ['202202', '2호선', '선릉', '943168', 155522, 835088, 137513, 20220303] 1.13
# ['202202', '2호선', '왕십리(성동구청)', '309677', 37874, 262066, 31804, 20220303] 1.19
# ['202202', '3호선', '교대(법원.검찰청)', '234824', 44949, 152403, 28122, 20220303] 1.6
# ['202202', '경부선', '서울역', '148368', 7191, 44210, 1823, 20220303] 3.94
# ['202201', '경부선', '서울역', '164651', 8252, 54080, 2032, 20220203] 4.06
# ['202112', '경부선', '서울역', '177398', 9415, 58435, 2303, 20220103] 4.09
# ['202111', '경부선', '서울역', '192711', 11755, 57522, 2741, 20211203] 4.29
# ['202110', '경부선', '서울역', '169652', 10900, 51551, 2523, 20211103] 4.32
# ['202105', '경부선', '서울역', '161256', 9134, 48854, 2091, 20210603] 4.37
# ['202104', '경부선', '서울역', '143397', 8861, 45176, 1980, 20210503] 4.48
# ['202006', '경부선', '서울역', '128591', 8084, 32963, 1672, 20200703] 4.83
# ['202001', '경부선', '서울역', '211635', 11567, 46598, 2139, 20200203] 5.41
# ...

# %% [markdown]
# ###rate = 유임 승차 인원/무임 승차 인원'

# %%
if row[6]!=0 and (row[4]+row[6])>=10000:
  rate=row[4]/(row[4]+row[6])

# %%
import csv
f=open("subwayfree.csv",encoding="cp949")
data=csv.reader(f)
next(data)
mx=0
rate=0

for row in data:
  for i in range(4,8):
    row[i]=int(row[i])
  if row[6]!=0 and (row[4]+row[6])>=10000:
    rate=row[4]/(row[4]+row[6])
    if row[6]!=0:
      rate=row[4]/row[6]
      if rate>mx:
        mx=rate
        print(row,round(rate,2))
# Out:
# ['202202', '1호선', '종로3가', '335905', 211468, 308127, 197301, 20220303] 1.07
# ['202202', '2호선', '선릉', '943168', 155522, 835088, 137513, 20220303] 1.13
# ['202202', '2호선', '왕십리(성동구청)', '309677', 37874, 262066, 31804, 20220303] 1.19
# ['202202', '3호선', '교대(법원.검찰청)', '234824', 44949, 152403, 28122, 20220303] 1.6
# ['202201', '3호선', '교대(법원.검찰청)', '281694', 51837, 182244, 32240, 20220203] 1.61
# ['202201', '경부선', '서울역', '164651', 8252, 54080, 2032, 20220203] 4.06
# ['202112', '경부선', '서울역', '177398', 9415, 58435, 2303, 20220103] 4.09
# ['202111', '경부선', '서울역', '192711', 11755, 57522, 2741, 20211203] 4.29
# ['202110', '경부선', '서울역', '169652', 10900, 51551, 2523, 20211103] 4.32
# ['202105', '경부선', '서울역', '161256', 9134, 48854, 2091, 20210603] 4.37
# ['202104', '경부선', '서울역', '143397', 8861, 45176, 1980, 20210503] 4.48
# ['202001', '경부선', '서울역', '211635', 11567, 46598, 2139, 20200203] 5.41
# ['201906', '경부선', '서울역', '207022', 13474, 43038, 2456, 20190703] 5.49
# ...

# %%
import csv
f=open("subwayfree.csv",encoding="cp949")
data=csv.reader(f)
next(data)
mx=0
rate=0

for row in data:
  for i in range(4,8):
    row[i]=int(row[i])
  if row[6]!=0 and (row[4]+row[6])>=10000:
    rate=row[4]/(row[4]+row[6])
    if row[6]!=0:
      rate=row[4]/row[6]
      if rate>mx:
        mx=rate
        mx_station = row[2]+" "+row[1] #역이름과 몇호선

print(mx_station,round(mx,2))
# Out:
# 한양대 2호선 29.05
